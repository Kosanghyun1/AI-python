# %% [markdown]
# <a href="https://colab.research.google.com/github/Kosanghyun1/AI-python/blob/main/260911.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("2주차")
print(10+20)
# Out:
# 2주차
# 30

# %%
import pandas as pd

# %%
a= 1
b = 2

print(a+b)
print(a-b)
print(a*b)
print(a/b) d
# Out:
# 3
# -1
# 2
# 0.5
