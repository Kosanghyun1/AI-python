# %%
print("hello")
# Out:
# hello

# %%
time =100
print(a , "분은 = ",a//60 , "시간 ", a % 60, "분 " )
# Out:
# 3 분은 =  0 시간  3 분

# %%
time = int(input('시간입력 : '))
print(time , "분은 = ",time//60 , "시간 ", time % 60, "분 " )
print(f" {time}분은 = {time//60}시간 {time % 60}분" )
# Out:
# 시간입력 :  100
# 100 분은 =  1 시간  40 분
#  100분은 = 1시간 40분

# %%
a=0
a = a+7
print(a)
# Out:
# 7

# %%
a=7
b=11

temp=a
a=b
b=temp
print(a)
# Out:
# 3

# %%
name = input('이름을 입력하세요: ')
age = int(input('나이를 입력하세요: '))
print(name, age)
print(type( age))
# Out:
# 이름을 입력하세요:
# 나이를 입력하세요:  d
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 2
#       1 name = input('이름을 입력하세요: ')
# ----> 2 age = int(input('나이를 입력하세요: '))
#       3 print(name, age)
#       4 print(type( age))
#
# ValueError: invalid literal for int() with base 10: 'd'

# %%
print(f'{name}님의 나이는 {age}세입니다.')
# Out:
# 님의 나이는 d세입니다.

# %%
americano_price = 2000
latte_price = 3000
green_tea_price = 2500

sum = 0          # 주문 금액을 저장할 변수를 0으로 초기화

americano_num = int(input('아메리카노 주문 수: '))
sum += americano_num * americano_price

latte_num = int(input('라떼 주문 수: '))
sum += latte_num * latte_price

green_tea_num = int(input('녹차 주문 수: '))
sum += green_tea_num * green_tea_price

print(f'전체 주문 금액은 {sum:,}원입니다.')
# Out:
# 아메리카노 주문 수:  5
# 라떼 주문 수:  5
# 녹차 주문 수:  5
# 전체 주문 금액은 37,500원입니다.

# %%
if False:
    print("참")
    
else :
    print("거짓")
# Out:
# 거짓

# %%
number = int(input('숫자를 입력하세요:'))

if number%2 == 0:
      print("짝수")
else : 
      print("홀수")
# Out:
# 숫자를 입력하세요:  10
# 짝수
