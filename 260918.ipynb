# %%
print("hello")
# Out:
# hello

# %%
time =100
print(a , "분은 = ",a//60 , "시간 ", a % 60, "분 " )
# Out:
# 100 분은 =  1 시간  40 분

# %%
a=0
a = a+7
print(a)
# Out:
# 7

# %%
a=7
b=11

temp=a
a=b
b=temp
print(a)
# Out:
# 3
